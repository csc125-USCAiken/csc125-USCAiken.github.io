# %% [markdown]
# <a href="https://colab.research.google.com/github/csc125-USCAiken/csc125-USCAiken.github.io/blob/master/Heart_of_computer_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart of computer science
# Solve problem using computers​
#
#
# *   Computer Systems  -- Hardware Support​
# *   Programming  --- Talk to computer ​
#
# > Python
#
# *   Data  --- input/output
# *   Algorithm  -- way to solve problem

# %% [markdown]
# # Computer Systems
# One or more CPUs, device controllers connect through common bus providing access to shared memory​
# ![Screenshot from 2020-08-24 10-46-17.png](data:image/png;base64,...)

# %% [markdown]
# Raspberry Pi - A mini desktop pc
# [raspberrypi.org](https://www.raspberrypi.org/products/)
#
#
# ![raspberry_pi_3_model_b_with_1gb_of_ram_with_wifi_and_bluetooth_low_energy_500x316_1579632515.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# CPU  --- Central process unit
#
# Memory  --- Hold data and program for CPU
#
# Motherboard --circuit board that connects main component
#
# Disk  ---- Store data and program
#
# Other devices  -- Monitor, Mouse, Keyboard and etc

# %% [markdown]
# ### Try it:

# %% [markdown]
# # Programming Language
#      **Talk to computer**
#
# 1.   General purpose high-level language
#
#      Java;Python;C++;C#
#
# 2.   System programming language
#
#      C
# 3.   Scripting language
#
#      Javascript;Php;Ruby
#
# 4.   Functional language
#
#      Lisp
#
# 5.   Logical Language
#      Prolog
#
#      Most popular languages: Javascript, Python, Java, C#

# %% [markdown]
# It does not matter how many programming languages you know.
#
# It matters how well you know one language.
#
# Syntax -- Not important
#
# ```
#  print("Hello world")     # python
#  window.alert("Hello world");  // Javascript
#  System.out.println("Hello world");  //Java
#  echo "hello world $name";     //php
#  cout << "Hello world";       // C++
#
# ```
# **Use programming language to mirror your thought **

# %% [markdown]
# ### Try it: Is C# a general purpose high level language?

# %% [markdown]
# # Algorithm
# This well-defined, ordered set of steps for solving a problem
#
# ## How Hard is it?
#  Task:   pay the gas bill​
#
# * Open the computer​
#
# * Access the gas company website​
#
# * Log in the account​
#
# * Click  make payment button​
#
# * Logout ​

# %% [markdown]
# ### Try it:   Anything missing from the algorithm?

# %% [markdown]
# # Roomba problem - Algorithm Challenge
#  [Picobot](https://cs.hmc.edu/picobot)
#
#  Clean up ----  pretty easy?​
#
# if your parents gave you a vacuum cleaner and told you to vacuum your room without missing a spot, you’d probably do a pretty great job without even thinking too much about it. Shouldn’t it be straightforward to convey your strategy to a robot?​
#
# Robot  - Limit​
#
# it can only sense what’s directly around it. ​
#
# Picobot is totally unfamiliar with the environment it is supposed to clean

# %% [markdown]
# ![pico1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![pico2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  ![pico3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Algorithm--- Rules- Picobot moves according to a set of rules of the form​
# ​
# StateNow   Surroundings   ->   MoveDirection   NewState​
#
# State : refer to the internal information that describes what a computer is doing.   ​
#
# “I am eating”​
#
# “I am going north”​
#
# ![Screenshot from 2020-08-25 00-42-06.png](data:image/png;base64,...)
#
# ​

# %% [markdown]
# # Let's try it. Command and Rules
#
# state  0    ------------ Going West​
#
# state   1     ------------Going East​
#
# If Picobot  is moving west and there is no wall to the west, then keep moving west.​
#
# `0 **x* -> W 0 ​`
#
# If Picobot is moving west and there is a wall to the west, then start moving east.​
#
# `0 **W* -> E 1​`
#
# If Picobot is moving east and there is no wall to the east, then keep moving east.​
#
# `1 *x** -> E 1`

# %% [markdown]
# ###Try it:  Rules that clean an empty room.
